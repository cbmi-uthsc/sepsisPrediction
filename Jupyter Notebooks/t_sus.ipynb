# %%
import pandas as pd
import math
import numpy as np
import collections

# %%
medication=pd.read_csv("medication.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
medication.sort_values(by=['drugorderoffset'],inplace=True)

# %%
microlab=pd.read_csv("microLab.csv")
microlab.head()
# Out:
#    microlabid  patientunitstayid  culturetakenoffset          culturesite  \
# 0      549559             983524                -688  Blood, Venipuncture
# 1      549555             983524               -5481                Stool
# 2      549565             983524                 324                Stool
# 3      549562             983524                -686  Blood, Central Line
# 4      549564             983524                -681  Blood, Central Line
#
#               organism antibiotic sensitivitylevel
# 0   gram positive rods        NaN              NaN
# 1            no growth        NaN              NaN
# 2            no growth        NaN              NaN
# 3   gram negative rods        NaN              NaN
# 4  gram positive cocci        NaN              NaN

# %%
microlab.sort_values(by=['culturetakenoffset'],inplace=True)

# %%
blood_cultures=microlab.loc[microlab['culturesite'].str.contains('Blood')]

# %%
count=0
for val in medication['routeadmin']:
    if val=='IV':
        count+=1

# %%
medication_2=medication.loc[medication['routeadmin']=='IV']

# %%
antibiotics_list=['adoxa','ala-tet','alodox','amikacin','amikin','amoxicillin','clavulanate','ampicillin',
                 'augmentin','avelox','avidoxy','azactam','azithromycin','aztreonam','axetil','bactocill',
                 'bactrim','bethkis','biaxin','bicillin l-a','cayston','cefazolin','cedax','cefoxitin',
                 'ceftazidime','cefaclor','cefadroxil','cefdinir','cefditoren','cefepime','cefotetan','cefotaxime',
                 'cefpodoxime','cefprozil','ceftibuten','ceftin','cefuroxime','cefuroxime','cephalexin','chloramphenicol',
                 'cipro','ciprofloxacin','claforan','clarithromycin','cleocin','clindamycin','cubicin','dicloxacillin',
                 'doryx','doxycycline','duricef','dynacin','ery-tab','eryped','eryc','erythrocin','erythromycin','factive',
                 'flagyl','fortaz','furadantin','garamycin','gentamicin','kanamycin','keflex','ketek','levaquin',
                 'levofloxacin','lincocin','macrobid','macrodantin','maxipime','mefoxin','metronidazole','minocin',
                 'minocycline','monodox','monurol','morgidox','moxatag','moxifloxacin','myrac','nafcillin sodium',
                 'nicazel doxy 30','nitrofurantoin','noroxin','ocudox','ofloxacin','omnicef','oracea','oraxyl','oxacillin',
                 'pc pen vk','pce dispertab','panixine','pediazole','penicillin','periostat','pfizerpen','piperacillin',
                 'tazobactam','primsol','proquin','raniclor','rifadin','rifampin','rocephin','smz-tmp','septra','septra ds',
                 'septra','solodyn','spectracef','streptomycin sulfate','sulfadiazine','sulfamethoxazole','trimethoprim',
                 'sulfatrim','sulfisoxazole','suprax','synercid','tazicef','tetracycline','timentin','tobi','tobramycin',
                 'trimethoprim','unasyn','vancocin','vancomycin','vantin','vibativ','vibra-tabs','vibramycin','zinacef',
                 'zithromax','zmax','zosyn','zyvox']

med_antibiotics=[]
for row in medication_2.itertuples():
    if(any(sub in str(row.drugname).lower() for sub in antibiotics_list)):
        med_antibiotics.append(row)

# %%
med_nonIV_anti=[]
for row in medication.itertuples():
    if(any(sub in str(row.drugname).lower() for sub in antibiotics_list)):
        med_nonIV_anti.append(row)

# %%
med_nonIV_anti=pd.DataFrame(med_nonIV_anti)
med_nonIV_anti.drop(columns=['Index'],inplace=True)

# %%
med_antibiotics=pd.DataFrame(med_antibiotics)
med_antibiotics.drop(columns=['Index'],inplace=True)

# %%
len(med_antibiotics)
# Out:
# 79754

# %%
t_sus_culture={}
for pid in blood_cultures['patientunitstayid'].unique():
    
    cultures=blood_cultures.loc[blood_cultures['patientunitstayid']==pid]
    cultures.sort_values(by=['culturetakenoffset'],inplace=True)
    earliest_culture=cultures['culturetakenoffset'].iloc[0]
    
    medication_pid=med_antibiotics.loc[med_antibiotics['patientunitstayid']==pid]
    medication_pid.sort_values(by=['drugorderoffset'],inplace=True)
    
    for i in range(len(medication_pid)):
        if(medication_pid['drugorderoffset'].iloc[i]>earliest_culture):
            timediff=abs(medication_pid['drugorderoffset'].iloc[i]-earliest_culture)
            
            if(timediff>(72*60)):
                break
            else:
                t_sus_culture[pid]=earliest_culture
                break
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
t_sus_culture
# Out:
# {}

# %%
for pid in microlab['patientunitstayid'].unique():
    print(med_nonIV_anti.loc[med_nonIV_anti['patientunitstayid']==pid])
# Out:
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 16457       91599288            2597831                1              -45
# 16458       92209867            2597831                1             -165
# 16459       92467683            2597831                1              675
# 110238      91290034            2597831             1665             1665
# 114665      89890968            2597831             2134             2625
# 136338      91483324            2597831             4801             4965
# 141432      90125413            2597831             5701             5692
# 144077      90914814            2597831             6354             6346
# 147459      90781524            2597831             7152             7605
# 167550      91429274            2597831            18971            18975
#
#        drugivadmixture drugordercancelled        drugname  drughiclseqno  \
# 16457              Yes                Yes  VANCOMYCIN HCL         4042.0
# 16458              Yes                Yes    AZITHROMYCIN         6334.0
# 16459              Yes                Yes  VANCOMYCIN HCL         4042.0
# 110238             Yes                Yes    AZITHROMYCIN         6334.0
# 114665             Yes                Yes  VANCOMYCIN HCL         4042.0
# 136338             Yes                Yes  VANCOMYCIN HCL         4042.0
# 141432              No                Yes  VANCOMYCIN HCL         4042.0
# 144077              No                Yes  VANCOMYCIN HCL         4042.0
# 147459             Yes                Yes  VANCOMYCIN HCL         4042.0
# 167550              No                 No    LEVOFLOXACIN        12384.0
#
#         dosage routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 16457      NaN         IV      Q12H         NaN  No           86354   19
# 16458   500 MG         IV      Q24H         NaN  No           86234   19
# 16459      NaN         IV      Q12H         NaN  No           87074   19
# 110238  500 MG         IV      Q24H         NaN  No           88064   19
# 114665    1 GM         IV      Q12H         NaN  No           89024   19
# 136338     NaN         IV      Q12H         NaN  No           91364   19
# 141432    1 GM     .ROUTE  .STK-MED         NaN  No          532733   99
# 144077    1 GM     .ROUTE  .STK-MED         NaN  No          533387   99
# 147459  500 MG         IV      Q12H         NaN  No           94004   19
# 167550  500 MG         PO       ONE         NaN  No          546016   19
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 172367      91356113            2600062            37890            37935
# 172368      92697355            2600062            37897            38655
# 172593      89731017            2600062            40954            41775
#
#        drugivadmixture drugordercancelled    drugname  drughiclseqno   dosage  \
# 172367             Yes                 No  VANCOMYCIN         4042.0  1500 MG
# 172368             Yes                 No  VANCOMYCIN         4042.0  1250 MG
# 172593             Yes                 No  VANCOMYCIN         4042.0   750 MG
#
#        routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 172367         IV       OTO         NaN  No           37936   20
# 172368         IV      Q12H         NaN  No           40952   20
# 172593         IV      Q12H         NaN  No           44934   20
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 115785     102239719            3050144             2241             2241
# 115821     102239729            3050144             2244             2243
# 130890     102241538            3050144             3963             3966
#
#        drugivadmixture drugordercancelled                     drugname  \
# 115785              No                 No  VANCOMYCIN 1.25 G/250 ML NS
# 115821              No                 No                     CEFEPIME
# 130890              No                 No   VANCOMYCIN 1.5 G/500 ML NS
#
#         drughiclseqno  dosage  routeadmin frequency loadingdose prn  \
# 115785         8466.0  250 ML  INTRAVENOU      Q12H         NaN  No
# 115821        10132.0     2 G  INTRAVENOU      Q8HR         NaN  No
# 130890         8466.0  500 ML  INTRAVENOU      Q12H         NaN  No
#
#         drugstopoffset  gtc
# 115785            3963   20
# 115821           45171   20
# 130890            5158   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#       medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 9046     102247272            3041223              -14               -6
#
#      drugivadmixture drugordercancelled                 drugname  \
# 9046              No                 No  PIPERACILLIN/TAZOBACTAM
#
#       drughiclseqno   dosage  routeadmin frequency loadingdose prn  \
# 9046         8738.0  3.375 G  INTRAVENOU       Q8H         NaN  No
#
#       drugstopoffset  gtc
# 9046           10537   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 76309      102319710            3114530              122              122
# 148930     104208008            3114530             7606             7605
# 154138     102332378            3114530             9366             9366
#
#        drugivadmixture drugordercancelled    drugname  drughiclseqno  dosage  \
# 76309               No                 No    CEFEPIME        10132.0     2 G
# 148930             Yes                 No  vancomycin         4042.0     NaN
# 154138              No                 No  vancomycin         4042.0  125 MG
#
#         routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 76309   INTRAVENOU     Q12HR         NaN  No            9844   20
# 148930  INTRAVENOU     Q12HR         NaN  No            9844   20
# 154138        ORAL      Q6HR         NaN  No            9844   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 55169      102244984            3104707               18               18
# 109539     102247271            3104707             1599             1599
# 142852     102253466            3104707             6013             6013
# 148625     102255550            3104707             7495             7495
#
#        drugivadmixture drugordercancelled                     drugname  \
# 55169               No                 No      PIPERACILLIN/TAZOBACTAM
# 109539              No                 No   VANCOMYCIN 1.5 G/500 ML NS
# 142852              No                 No  METRONIDAZOLE 500 MG/100 ML
# 148625              No                 No                metroNIDAZOLE
#
#         drughiclseqno  dosage  routeadmin frequency loadingdose prn  \
# 55169          8738.0     NaN  INTRAVENOU      Q8HR         NaN  No
# 109539         8466.0  500 ML  INTRAVENOU   ONETIME         NaN  No
# 142852         8259.0  100 ML  INTRAVENOU      Q8HR         NaN  No
# 148625         4157.0  500 MG        ORAL      Q8HR         NaN  No
#
#         drugstopoffset  gtc
# 55169             3168   20
# 109539            3039   20
# 142852            7495   23
# 148625            7719   23
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 101042     102319298            3069155             1030             1030
#
#        drugivadmixture drugordercancelled   drugname  drughiclseqno dosage  \
# 101042              No                 No  ceFAZolin         3976.0    1 G
#
#         routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 101042  INTRAVENOU      Q8HR         NaN  No            2478   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 4599       102278763            3046782              -80             -198
# 4606       102278758            3046782              -80             -447
# 4624       102278761            3046782              -80             -200
# 72240      102279175            3046782               91               91
# 102922     102280283            3046782             1138             1138
#
#        drugivadmixture drugordercancelled                   drugname  \
# 4599                No                 No               azithromycin
# 4606                No                 No  VANCOMYCIN 1 G/200 ML D5W
# 4624                No                 No  VANCOMYCIN 1 G/200 ML D5W
# 72240               No                 No               azithromycin
# 102922              No                 No               azithromycin
#
#         drughiclseqno  dosage  routeadmin     frequency loadingdose prn  \
# 4599           6334.0  500 MG        ORAL  DAILY (0900)         NaN  No
# 4606           8466.0  200 ML  INTRAVENOU      PYX1TIME         NaN  No
# 4624           8466.0  200 ML  INTRAVENOU         Q24HR         NaN  No
# 72240          6334.0  500 MG  INTRAVENOU         Q24HR         NaN  No
# 102922         6334.0  500 MG        ORAL  DAILY (0900)         NaN  No
#
#         drugstopoffset  gtc
# 4599                91   20
# 4606              -447   20
# 4624              1092   20
# 72240              885   20
# 102922            2579   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 99052      102281302            3051218              915              923
# 125688     102284472            3051218             3262             3261
# 127867     102284886            3051218             3579             3593
# 146058     102290351            3051218             6834             6848
# 171772     102325463            3051218            31982            31981
# 171811     104207855            3051218            32274            32274
#
#        drugivadmixture drugordercancelled                   drugname  \
# 99052               No                 No  VANCOMYCIN 1 G/200 ML D5W
# 125688              No                 No    CEFAZOLIN 2 G/100 ML NS
# 127867              No                 No    PIPERACILLIN/TAZOBACTAM
# 146058              No                 No    PIPERACILLIN/TAZOBACTAM
# 171772              No                 No               LEVOFLOXACIN
# 171811              No                 No    CEFAZOLIN 2 G/100 ML NS
#
#         drughiclseqno   dosage  routeadmin frequency loadingdose prn  \
# 99052          8466.0   200 ML  INTRAVENOU      Q12H         NaN  No
# 125688         3976.0   100 ML  INTRAVENOU      Q8HR         NaN  No
# 127867         8738.0  3.375 G  INTRAVENOU       Q8H         NaN  No
# 146058         8738.0  3.375 G  INTRAVENOU       Q8H         NaN  No
# 171772        12384.0   500 MG        ORAL     Q24HR         NaN  No
# 171811         3976.0   100 ML  INTRAVENOU      Q8HR         NaN  No
#
#         drugstopoffset  gtc
# 99052             3257   20
# 125688            3579   20
# 127867            6831   20
# 146058           31981   20
# 171772           33461   20
# 171811           75398   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#        medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 1595      102279312            3101424             -250             -358
# 62716     102279681            3101424               42               42
#
#       drugivadmixture drugordercancelled                     drugname  \
# 1595               No                 No  METRONIDAZOLE 500 MG/100 ML
# 62716              No                 No  METRONIDAZOLE 500 MG/100 ML
#
#        drughiclseqno  dosage  routeadmin frequency loadingdose prn  \
# 1595          8259.0  100 ML  INTRAVENOU      Q8HR         NaN  No
# 62716         8259.0  100 ML  INTRAVENOU      Q8HR         NaN  No
#
#        drugstopoffset  gtc
# 1595               39   23
# 62716           42967   23
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 112923     102211822            3050145             1953             1962
# 128448     102213591            3050145             3656             3657
# 128559     102213603            3050145             3670             3672
#
#        drugivadmixture drugordercancelled                    drugname  \
# 112923              No                 No   VANCOMYCIN 1 G/200 ML D5W
# 128448             Yes                 No                  vancomycin
# 128559              No                 No  VANCOMYCIN 1.5 G/500 ML NS
#
#         drughiclseqno  dosage  routeadmin frequency loadingdose prn  \
# 112923         8466.0  200 ML  INTRAVENOU      Q12H         NaN  No
# 128448         4042.0     1 G  INTRAVENOU      Q12H         NaN  No
# 128559         8466.0  500 ML  INTRAVENOU      Q12H         NaN  No
#
#         drugstopoffset  gtc
# 112923            3655   20
# 128448            3670   20
# 128559            5448   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 88822      102293655            3058853              369              378
# 88843      102293656            3058853              370              378
# 146577     102303442            3058853             6947             6947
# 146580     102303133            3058853             6947             6947
# 149774     102304925            3058853             7914             7914
# 150147     102305127            3058853             8023             8028
# 164940     102315548            3058853            15762            15762
# 166494     102318522            3058853            17504            17504
# 170150     102327801            3058853            24567            24567
# 172251     102343907            3058853            36327            36327
# 172252     102343909            3058853            36328            36328
#
#        drugivadmixture drugordercancelled                     drugname  \
# 88822               No                 No    VANCOMYCIN 1 G/200 ML D5W
# 88843               No                 No      PIPERACILLIN/TAZOBACTAM
# 146577              No                 No                   vancomycin
# 146580              No                 No  METRONIDAZOLE 500 MG/100 ML
# 149774              No                 No      PIPERACILLIN/TAZOBACTAM
# 150147              No                 No      PIPERACILLIN/TAZOBACTAM
# 164940              No                 No                   vancomycin
# 166494              No                 No  METRONIDAZOLE 500 MG/100 ML
# 170150              No                 No      PIPERACILLIN/TAZOBACTAM
# 172251              No                 No  METRONIDAZOLE 500 MG/100 ML
# 172252              No                 No      PIPERACILLIN/TAZOBACTAM
#
#         drughiclseqno   dosage  routeadmin frequency loadingdose prn  \
# 88822          8466.0   200 ML  INTRAVENOU      Q12H         NaN  No
# 88843          8738.0  3.375 G  INTRAVENOU       Q8H         NaN  No
# 146577         4042.0   125 MG        ORAL       NaN         NaN  No
# 146580         8259.0   100 ML  INTRAVENOU      Q8HR         NaN  No
# 149774         8738.0     1 ML  INTRAVENOU  PYX1TIME         NaN  No
# 150147         8738.0  3.375 G  INTRAVENOU       Q8H         NaN  No
# 164940         4042.0   500 MG        ORAL       NaN         NaN  No
# 166494         8259.0   100 ML  INTRAVENOU      Q8HR         NaN  No
# 170150         8738.0      NaN  INTRAVENOU      Q8HR         NaN  No
# 172251         8259.0   100 ML  INTRAVENOU      Q8HR         NaN  No
# 172252         8738.0  3.375 G  INTRAVENOU      Q8HR         NaN  No
#
#         drugstopoffset  gtc
# 88822             5679   20
# 88843             8022   20
# 146577            7540   20
# 146580            7540   23
# 149774            7914   20
# 150147           24566   20
# 164940           17504   20
# 166494           21800   23
# 170150           28082   20
# 172251           43321   23
# 172252           43321   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#        medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 45653      92412673            2631372                4            -2686
# 45655      91613041            2631372                4            -1846
# 45656      91815886            2631372                4            -6646
# 45657      89702599            2631372                4            -7426
#
#       drugivadmixture drugordercancelled    drugname  drughiclseqno   dosage  \
# 45653             Yes                 No  VANCOMYCIN         4042.0   750 MG
# 45655             Yes                 No  VANCOMYCIN         4042.0   500 MG
# 45656             Yes                 No  VANCOMYCIN         4042.0  1250 MG
# 45657             Yes                 No  VANCOMYCIN         4042.0  1500 MG
#
#       routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 45653         IV      Q12H         NaN  No           -1943   20
# 45655         IV       BID         NaN  No           -1882   20
# 45656         IV      Q12H         NaN  No           -2998   20
# 45657         IV       OTO         NaN  No           -7425   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 166117     102295380            3085675            17072            17669
# 166118     102295379            3085675            17072            17072
#
#        drugivadmixture drugordercancelled      drugname  drughiclseqno  \
# 166117              No                 No  LEVOFLOXACIN        12384.0
# 166118              No                 No  LEVOFLOXACIN        12384.0
#
#         dosage routeadmin     frequency loadingdose prn  drugstopoffset  gtc
# 166117  250 MG       ORAL  DAILY (0900)         NaN  No           59954   20
# 166118  500 MG       ORAL       ONETIME         NaN  No           17653   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# ...
# 154819      92748506            2644964             9611            10361
#
#        drugivadmixture drugordercancelled    drugname  drughiclseqno   dosage  \
# 154796             Yes                 No    CEFEPIME            NaN     2 GM
# 154803             Yes                 No  VANCOMYCIN         4042.0  2000 MG
# 154819             Yes                 No  VANCOMYCIN         4042.0  1500 MG
#
#        routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 154796         IV       Q8H         NaN  No           12558    0
# 154803         IV       OTO         NaN  No            9642   20
# 154819         IV     Q12HR         NaN  No           12558   20
#        medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 97624      89888227            2589947              834              868
#
#       drugivadmixture drugordercancelled    drugname  drughiclseqno   dosage  \
# 97624             Yes                 No  VANCOMYCIN         4042.0  1500 MG
#
#       routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 97624         IV      Q8HR         NaN  No             890   20
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 94379       92340409            2646289              651              674
# 130417      90674507            2646289             3903             3914
# 133447      91963276            2646289             4286             4634
# 148715      91736942            2646289             7528             7994
# 158850      90004804            2646289            11390            12314
# 164267      89664948            2646289            15184            15194
# 164274      91559325            2646289            15188            15194
# 164738      90244523            2646289            15564            15614
# 164936      90815663            2646289            15761            16094
#
#        drugivadmixture drugordercancelled        drugname  drughiclseqno  \
# 94379              Yes                 No  VANCOMYCIN HCL         4042.0
# 130417             Yes                 No  VANCOMYCIN HCL         4042.0
# 133447             Yes                Yes  VANCOMYCIN HCL         4042.0
# 148715             Yes                Yes  VANCOMYCIN HCL         4042.0
# 158850             Yes                Yes  VANCOMYCIN HCL         4042.0
# 164267             Yes                Yes  VANCOMYCIN HCL         4042.0
# 164274             Yes                 No  VANCOMYCIN HCL         4042.0
# 164738             Yes                Yes  VANCOMYCIN HCL         4042.0
# 164936             Yes                Yes  VANCOMYCIN HCL         4042.0
#
#         dosage routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 94379     2 GM         IV       ONE         NaN  No          526363   19
# 130417    1 GM         IV       ONE         NaN  No          529573   19
# 133447    1 GM         IV      Q12H         NaN  No           24793   19
# 148715  500 MG         IV      Q24H         NaN  No           28153   19
# 158850  500 MG         IV      Q24H         NaN  No           32473   19
# 164267     NaN         IV       ONE         NaN  No          540853   19
# 164274     NaN         IV       ONE         NaN  No          540853   19
# 164738     NaN         IV       Q8H         NaN  No           35773   19
# 164936     NaN         IV       Q8H         NaN  No           36253   19
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 116148      90959588            2628798             2273             3757
# 116149      90031293            2628798             2273             2317
# 144820      90678058            2628798             6549             6577
# 144831      90313905            2628798             6550             8017
# 154492      90137714            2628798             9497             9517
#
#        drugivadmixture drugordercancelled        drugname  drughiclseqno  \
# 116148             Yes                Yes  VANCOMYCIN HCL         4042.0
# 116149             Yes                 No  VANCOMYCIN HCL         4042.0
# 144820             Yes                 No  VANCOMYCIN HCL         4042.0
# 144831             Yes                Yes  VANCOMYCIN HCL         4042.0
# 154492             Yes                Yes  VANCOMYCIN HCL         4042.0
#
#         dosage routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 116148  500 MG         IV      Q24H         NaN  No           23916   19
# 116149    1 GM         IV       ONE         NaN  No          529416   19
# 144820    1 GM         IV       ONE         NaN  No          533676   19
# 144831  500 MG         IV      Q24H         NaN  No           28176   19
# 154492  750 MG         IV      Q24H         NaN  No           29676   19
#        medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 81170      92022122            2619909              180              741
# 81171      91144786            2619909              180              261
#
#       drugivadmixture drugordercancelled        drugname  drughiclseqno  \
# 81170             Yes                Yes  VANCOMYCIN HCL         4042.0
# 81171             Yes                 No  VANCOMYCIN HCL         4042.0
#
#       dosage routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 81170    NaN         IV       Q8H         NaN  No           20900   19
# 81171    NaN         IV       ONE         NaN  No          527390   19
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
#         medicationid  patientunitstayid  drugorderoffset  drugstartoffset  \
# 120086      92288746            2575922             2623             2742
# 158091      90486230            2575922            11042            11322
# 161122      91471177            2575922            12751            12822
# 163189      91519548            2575922            14230            14262
# 164775      90326167            2575922            15606            15702
# 166066      92761210            2575922            17010            17082
# 169591      90393867            2575922            23041            23082
#
#        drugivadmixture drugordercancelled    drugname  drughiclseqno   dosage  \
# 120086             Yes                 No  VANCOMYCIN         4042.0  2000 MG
# 158091             Yes                 No  VANCOMYCIN         4042.0   250 MG
# 161122             Yes                 No  VANCOMYCIN         4042.0   250 MG
# 163189             Yes                 No  VANCOMYCIN         4042.0   250 MG
# 164775             Yes                 No  VANCOMYCIN         4042.0   250 MG
# 166066             Yes                 No  VANCOMYCIN         4042.0   250 MG
# 169591             Yes                 No    CEFEPIME            NaN     1 GM
#
#        routeadmin frequency loadingdose prn  drugstopoffset  gtc
# 120086         IV       OTO         NaN  No            2743   20
# 158091         IV     Q24HR         NaN  No           11323   20
# 161122         IV       OTO         NaN  No           12823   20
# 163189         IV       OTO         NaN  No           14263   20
# 164775         IV       OTO         NaN  No           15703   20
# 166066         IV       OTO         NaN  No           17083   20
# 169591         IV       QPM         NaN  No           33125    0
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
# Empty DataFrame
# Columns: [medicationid, patientunitstayid, drugorderoffset, drugstartoffset, drugivadmixture, drugordercancelled, drugname, drughiclseqno, dosage, routeadmin, frequency, loadingdose, prn, drugstopoffset, gtc]
# Index: []
