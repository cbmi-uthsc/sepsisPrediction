# %%
import pandas as pd
import numpy as np

# %%
respiratory=pd.read_csv("respiratoryCharting.csv", chunksize=10000)

# %%
l_r=[]
for chunk in respiratory:
    l_r.append(chunk)

# %%
len(l_r)
# Out:
# 2017

# %%
df_resp=pd.concat(l_r, sort=False)

# %%
df_resp.head()
# Out:
#    respchartid  patientunitstayid  respchartoffset  respchartentryoffset  \
# 0            3             221468             4679                  4679
# 1            4             221468             4679                  4679
# 2            5             221468             4679                  4679
# 3            6             221468             4679                  4679
# 4            7             221468             4679                  4679
#
#    respcharttypecat respchartvaluelabel respchartvalue
# 0  respFlowCareData      RT Vent On/Off      Continued
# 1  respFlowSettings                FiO2             40
# 2  respFlowSettings           Vent Rate             14
# 3  respFlowSettings  Tidal Volume (set)            450
# 4  respFlowSettings           TV/kg IBW         5.4720

# %%
respFiO2=df_resp.loc[df_resp['respchartvaluelabel']=='FiO2']

# %%
respFiO2.head()
# Out:
#     respchartid  patientunitstayid  respchartoffset  respchartentryoffset  \
# 1             4             221468             4679                  4679
# 15           60             152518            27557                 27557
# 22           81             204319             1917                  1917
# 24           85             241257             4468                  4468
# 26          105             192236            27137                 27137
#
#     respcharttypecat respchartvaluelabel respchartvalue
# 1   respFlowSettings                FiO2             40
# 15  respFlowSettings                FiO2             50
# 22  respFlowSettings                FiO2             60
# 24  respFlowSettings                FiO2             70
# 26  respFlowSettings                FiO2             40

# %%
respFiO2.loc[respFiO2['respchartvalue']==0, 'respchartvalue']=1

# %%
respFiO2['respchartvalue']=respFiO2['respchartvalue'].str.replace('%','')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
respFiO2=respFiO2[['patientunitstayid','respchartentryoffset', 'respchartvaluelabel', 'respchartvalue']]

# %%
respFiO2.dtypes
# Out:
# patientunitstayid         int32
# respchartentryoffset      int32
# respchartvaluelabel      object
# respchartvalue          float32
# dtype: object

# %%
respFiO2[['patientunitstayid','respchartentryoffset']]=respFiO2[['patientunitstayid','respchartentryoffset']].astype('int32')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
respFiO2[['respchartvalue']]=respFiO2[['respchartvalue']].astype('str').astype('float32')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df_lab=pd.read_csv("labs_before_FiO2.csv")
df_lab['paO2_FiO2']=np.nan

# %%
df_lab.head()
# Out:
#    patientunitstayid  labresultoffset             labname  labresult  \
# 0             141168             1701  urinary creatinine     173.12
# 1             141168             2026                paO2      68.00
# 2             141168             2141                paO2     121.00
# 3             141168             1133    platelets x 1000     213.00
# 4             141168             2010                paO2      42.00
#
#   labmeasurenamesystem labmeasurenameinterface  labresultrevisedoffset  \
# 0                mg/dL                   mg/dL                    1757
# 1                mm Hg                   mm Hg                    2054
# 2                mm Hg                   mm Hg                    2155
# 3                K/mcL                   K/mcL                    1196
# 4                mm Hg                   mm Hg                    2026
#
#    paO2_FiO2
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df_lab=df_lab[['patientunitstayid', 'labresultoffset', 'labname', 'labresult', 'paO2_FiO2' ]]

# %%
df_lab.dtypes
# Out:
# patientunitstayid      int64
# labresultoffset        int64
# labname               object
# labresult            float64
# paO2_FiO2            float64
# dtype: object

# %%
df_lab[['patientunitstayid','labresultoffset']]=df_lab[['patientunitstayid','labresultoffset']].astype('int32')

# %%
df_lab[['labresult','paO2_FiO2']]=df_lab[['labresult','paO2_FiO2']].astype('float32')

# %% [markdown]
# <h1>WARNING! The next block of code takes about 15 hours to run. Please keep that in mind.
# If the processed csv is needed, please contact me</h1>

# %%
count=0
for row in df_lab.itertuples():
    if (row.labname=='paO2'):
        pid=row.patientunitstayid
        toffset=row.labresultoffset
        index=row.Index
        if(any(respFiO2.loc[(respFiO2['patientunitstayid']==pid) & ((respFiO2['respchartentryoffset']<=toffset+200) & (respFiO2['respchartentryoffset']>=toffset-200)),'respchartvalue'].values)):
            result = row.labresult/(respFiO2.loc[(respFiO2['patientunitstayid']==pid) & ((respFiO2['respchartentryoffset']<=toffset+200) & (respFiO2['respchartentryoffset']>=toffset-200)),'respchartvalue'].iloc[0]/100)
            df_lab['paO2_FiO2'][index]=result      
        else:
            df_lab['paO2_FiO2'][index]=df_lab['paO2_FiO2'].mean()
    count+=1
    if((count%10000)==0):
        print(count)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# 10000
# 20000
# 30000
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in double_scalars
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# 1140000
# 1150000
# 1160000
# 1170000
# 1180000
# 1190000
# 1200000
# 1210000
# 1220000
# 1230000
# 1240000
# 1250000
# 1260000
# 1270000
# 1280000
# 1290000
# 1300000
# 1310000
# 1320000
# 1330000
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# 1390000
# 1400000
# 1410000
# 1420000
# 1430000
# 1440000
# 1450000
# 1460000
# 1470000
# 1480000
# 1490000
# 1500000
# 1510000
# 1520000
# 1530000
# 1540000
# 1550000
# 1560000
# 1570000
# 1580000
# 1590000
# 1600000
# 1610000
# 1620000
# 1630000
# 1640000
# 1650000
# 1660000
# 1670000
# 1680000
# 1690000
# 1700000
# 1710000
# 1720000
# 1730000
# 1740000
# 1750000
# 1760000
# 1770000
# 1780000
# 1790000
# 1800000
# 1810000
# 1820000
# 1830000
# 1840000
# 1850000
# 1860000
# 1870000
# 1880000
# 1890000
# 1900000
# 1910000
# 1920000
# 1930000
# 1940000
# 1950000
# 1960000
# 1970000
# 1980000
# 1990000
# 2000000
# 2010000

# %%
for pid in df_lab['patientunitstayid'].unique():
    df_lab.loc['']

# %%
df_lab.head()

# %%
respFiO2.loc[(respFiO2['patientunitstayid']==147037) & ((respFiO2['respchartentryoffset']<=4100+200) & (respFiO2['respchartentryoffset']>=4100-200)),'respchartvalue']
# Out:
# Series([], Name: respchartvalue, dtype: object)

# %%
df_lab.iloc[750]
# Out:
# patientunitstayid              147037
# labresultoffset                 -1975
# labname              platelets x 1000
# labresult                         185
# paO2_FiO2
# Name: 7570, dtype: object

# %%
len(df_lab.loc[df_lab['labname']=='paO2'])
# Out:
# 420762

# %%
np.ones((len(df_lab),1))
# Out:
# numpy.ndarray

# %%
df_lab['labresult'].mean()
# Out:
# 151.67764282226562

# %%
arr.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-f51c330b97d4> in <module>
# ----> 1 arr.append(2)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
import csv

# %%
df_lab.to_csv("labs_after_FiO2.csv", sep=',', index=False, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a41f8bd2cbc> in <module>
# ----> 1 df_lab.to_csv("labs_after_FiO2.csv", sep=',', index=False, encoding='utf-8')
#
# NameError: name 'df_lab' is not defined

# %% [markdown]
# <h1>Continue from here</h1>

# %%
pre_final_lab=pd.read_csv("labs_after_FiO2.csv")

# %%
pre_final_lab['platelets_x_1000']=np.nan
pre_final_lab['total_bilirubin']=np.nan
pre_final_lab['urinary_creatinine']=np.nan

# %%
pre_final_lab['platelets_x_1000']=pre_final_lab.loc[pre_final_lab['labname']=='platelets x 1000','labresult']
pre_final_lab['total_bilirubin']=pre_final_lab.loc[pre_final_lab['labname']=='total bilirubin','labresult']
pre_final_lab['urinary_creatinine']=pre_final_lab.loc[pre_final_lab['labname']=='urinary creatinine','labresult']

# %%
pre_final_lab
# Out:
#          patientunitstayid  labresultoffset             labname  labresult  \
# 0                   141168             1701  urinary creatinine     173.12
# 1                   141168             2026                paO2      68.00
# 2                   141168             2141                paO2     121.00
# 3                   141168             1133    platelets x 1000     213.00
# 4                   141168             2010                paO2      42.00
# 5                   141168             2026     total bilirubin       5.20
# 6                   141168             2026    platelets x 1000     187.00
# 7                   141168             1805                paO2      41.00
# 8                   141168              516     total bilirubin       2.60
# 9                   141168             1133     total bilirubin       4.10
# 10                  141168              516    platelets x 1000     209.00
# 11                  141178             -280    platelets x 1000     273.00
# 12                  141178             -280     total bilirubin       0.40
# 13                  141179             1487    platelets x 1000     219.00
# 14                  141194             7303    platelets x 1000     139.00
# 15                  141194             2102                paO2     100.00
# 16                  141194              312     total bilirubin       0.40
# 17                  141194             1630    platelets x 1000     199.00
# 18                  141194             8762    platelets x 1000     158.00
# 19                  141194             -923     total bilirubin       0.40
# 20                  141194             -923    platelets x 1000     298.00
# 21                  141194             2998    platelets x 1000     146.00
# 22                  141194            11658    platelets x 1000     265.00
# 23                  141194              312    platelets x 1000     233.00
# 24                  141194             4663    platelets x 1000     142.00
# 25                  141194            10397    platelets x 1000     200.00
# 26                  141194             5897    platelets x 1000     125.00
# 27                  141196             3600     total bilirubin       0.30
# 28                  141196             4987    platelets x 1000     504.00
# 29                  141196             1030                paO2      70.00
# ...                    ...              ...                 ...        ...
# 2010809            3353251             -169                paO2     246.00
# 2010810            3353251            11054                paO2      87.00
# 2010811            3353251             9901                paO2      80.00
# 2010812            3353251              -50                paO2     163.00
# 2010813            3353251             1065                paO2      89.00
# 2010814            3353251             2541    platelets x 1000     205.00
# 2010815            3353251             1490    platelets x 1000     202.00
# 2010816            3353251              -60     total bilirubin       0.50
# 2010817            3353251             5459    platelets x 1000     106.00
# 2010818            3353251             4510                paO2      72.00
# 2010819            3353251              -60    platelets x 1000     232.00
# 2010820            3353251             5598                paO2      68.00
# 2010821            3353251             1127    platelets x 1000     196.00
# 2010822            3353251              972                paO2     153.00
# 2010823            3353251               82                paO2     136.00
# 2010824            3353251             6868    platelets x 1000     129.00
# 2010825            3353251             2448                paO2      71.00
# 2010826            3353251              310                paO2      94.00
# 2010827            3353254             5558    platelets x 1000     185.00
# 2010828            3353254             -256    platelets x 1000     268.00
# 2010829            3353254             -256     total bilirubin       0.40
# 2010830            3353254             4237                paO2      57.00
# 2010831            3353254             1218    platelets x 1000     183.00
# 2010832            3353254             2610    platelets x 1000     132.00
# 2010833            3353254             4143    platelets x 1000     158.00
# 2010834            3353263             7490    platelets x 1000     246.00
# 2010835            3353263             3048    platelets x 1000     180.00
# 2010836            3353263               -7    platelets x 1000     161.00
# 2010837            3353263               -7    platelets x 1000     164.00
# 2010838            3353263             1733    platelets x 1000     169.00
#
#           paO2_FiO2  platelets_x_1000  total_bilirubin  urinary_creatinine
# 0               NaN               NaN              NaN              173.12
# 1        136.000000               NaN              NaN                 NaN
# 2        121.000000               NaN              NaN                 NaN
# 3               NaN             213.0              NaN                 NaN
# 4         84.000000               NaN              NaN                 NaN
# 5               NaN               NaN              5.2                 NaN
# 6               NaN             187.0              NaN                 NaN
# 7         82.000000               NaN              NaN                 NaN
# 8               NaN               NaN              2.6                 NaN
# 9               NaN               NaN              4.1                 NaN
# 10              NaN             209.0              NaN                 NaN
# 11              NaN             273.0              NaN                 NaN
# 12              NaN               NaN              0.4                 NaN
# 13              NaN             219.0              NaN                 NaN
# 14              NaN             139.0              NaN                 NaN
# 15       263.923680               NaN              NaN                 NaN
# 16              NaN               NaN              0.4                 NaN
# 17              NaN             199.0              NaN                 NaN
# 18              NaN             158.0              NaN                 NaN
# 19              NaN               NaN              0.4                 NaN
# 20              NaN             298.0              NaN                 NaN
# 21              NaN             146.0              NaN                 NaN
# 22              NaN             265.0              NaN                 NaN
# 23              NaN             233.0              NaN                 NaN
# 24              NaN             142.0              NaN                 NaN
# 25              NaN             200.0              NaN                 NaN
# 26              NaN             125.0              NaN                 NaN
# 27              NaN               NaN              0.3                 NaN
# 28              NaN             504.0              NaN                 NaN
# 29       263.944700               NaN              NaN                 NaN
# ...             ...               ...              ...                 ...
# 2010809  246.000000               NaN              NaN                 NaN
# 2010810  217.500000               NaN              NaN                 NaN
# 2010811  177.777770               NaN              NaN                 NaN
# 2010812  163.000000               NaN              NaN                 NaN
# 2010813  111.250000               NaN              NaN                 NaN
# 2010814         NaN             205.0              NaN                 NaN
# 2010815         NaN             202.0              NaN                 NaN
# 2010816         NaN               NaN              0.5                 NaN
# 2010817         NaN             106.0              NaN                 NaN
# 2010818  180.000000               NaN              NaN                 NaN
# 2010819         NaN             232.0              NaN                 NaN
# 2010820  170.000000               NaN              NaN                 NaN
# 2010821         NaN             196.0              NaN                 NaN
# 2010822  191.250000               NaN              NaN                 NaN
# 2010823  136.000000               NaN              NaN                 NaN
# 2010824         NaN             129.0              NaN                 NaN
# 2010825  118.333336               NaN              NaN                 NaN
# 2010826   94.000000               NaN              NaN                 NaN
# 2010827         NaN             185.0              NaN                 NaN
# 2010828         NaN             268.0              NaN                 NaN
# 2010829         NaN               NaN              0.4                 NaN
# 2010830         inf               NaN              NaN                 NaN
# 2010831         NaN             183.0              NaN                 NaN
# 2010832         NaN             132.0              NaN                 NaN
# 2010833         NaN             158.0              NaN                 NaN
# 2010834         NaN             246.0              NaN                 NaN
# 2010835         NaN             180.0              NaN                 NaN
# 2010836         NaN             161.0              NaN                 NaN
# 2010837         NaN             164.0              NaN                 NaN
# 2010838         NaN             169.0              NaN                 NaN
#
# [2010839 rows x 8 columns]

# %%
pre_final_lab=pre_final_lab.replace([np.inf, -np.inf], np.nan)

# %%
del pre_final_lab['labresult']

# %%
pre_final_lab
# Out:
#          patientunitstayid  labresultoffset             labname   paO2_FiO2  \
# 0                   141168             1701  urinary creatinine         NaN
# 1                   141168             2026                paO2  136.000000
# 2                   141168             2141                paO2  121.000000
# 3                   141168             1133    platelets x 1000  121.000000
# 4                   141168             2010                paO2   84.000000
# 5                   141168             2026     total bilirubin   84.000000
# 6                   141168             2026    platelets x 1000   84.000000
# 7                   141168             1805                paO2   82.000000
# 8                   141168              516     total bilirubin   82.000000
# 9                   141168             1133     total bilirubin   82.000000
# 10                  141168              516    platelets x 1000   82.000000
# 11                  141178             -280    platelets x 1000   82.000000
# 12                  141178             -280     total bilirubin   82.000000
# 13                  141179             1487    platelets x 1000         NaN
# 14                  141194             7303    platelets x 1000         NaN
# 15                  141194             2102                paO2  263.923680
# 16                  141194              312     total bilirubin  263.923680
# 17                  141194             1630    platelets x 1000  263.923680
# 18                  141194             8762    platelets x 1000  263.923680
# 19                  141194             -923     total bilirubin  263.923680
# 20                  141194             -923    platelets x 1000  263.923680
# 21                  141194             2998    platelets x 1000         NaN
# 22                  141194            11658    platelets x 1000         NaN
# 23                  141194              312    platelets x 1000         NaN
# 24                  141194             4663    platelets x 1000         NaN
# 25                  141194            10397    platelets x 1000         NaN
# 26                  141194             5897    platelets x 1000         NaN
# 27                  141196             3600     total bilirubin         NaN
# 28                  141196             4987    platelets x 1000         NaN
# 29                  141196             1030                paO2  263.944700
# ...                    ...              ...                 ...         ...
# 2010809            3353251             -169                paO2  246.000000
# 2010810            3353251            11054                paO2  217.500000
# 2010811            3353251             9901                paO2  177.777770
# 2010812            3353251              -50                paO2  163.000000
# 2010813            3353251             1065                paO2  111.250000
# 2010814            3353251             2541    platelets x 1000  111.250000
# 2010815            3353251             1490    platelets x 1000  111.250000
# 2010816            3353251              -60     total bilirubin  111.250000
# 2010817            3353251             5459    platelets x 1000  111.250000
# 2010818            3353251             4510                paO2  180.000000
# 2010819            3353251              -60    platelets x 1000  180.000000
# 2010820            3353251             5598                paO2  170.000000
# 2010821            3353251             1127    platelets x 1000  170.000000
# 2010822            3353251              972                paO2  191.250000
# 2010823            3353251               82                paO2  136.000000
# 2010824            3353251             6868    platelets x 1000  136.000000
# 2010825            3353251             2448                paO2  118.333336
# 2010826            3353251              310                paO2   94.000000
# 2010827            3353254             5558    platelets x 1000   94.000000
# 2010828            3353254             -256    platelets x 1000   94.000000
# 2010829            3353254             -256     total bilirubin   94.000000
# 2010830            3353254             4237                paO2   94.000000
# 2010831            3353254             1218    platelets x 1000   94.000000
# 2010832            3353254             2610    platelets x 1000         NaN
# 2010833            3353254             4143    platelets x 1000         NaN
# 2010834            3353263             7490    platelets x 1000         NaN
# 2010835            3353263             3048    platelets x 1000         NaN
# 2010836            3353263               -7    platelets x 1000         NaN
# 2010837            3353263               -7    platelets x 1000         NaN
# 2010838            3353263             1733    platelets x 1000         NaN
#
#          platelets_x_1000  total_bilirubin  urinary_creatinine
# 0                     NaN              NaN              173.12
# 1                     NaN              NaN              173.12
# 2                     NaN              NaN              173.12
# 3                   213.0              NaN              173.12
# 4                   213.0              NaN              173.12
# 5                   213.0              5.2              173.12
# 6                   187.0              5.2                 NaN
# 7                   187.0              5.2                 NaN
# 8                   187.0              2.6                 NaN
# 9                   187.0              4.1                 NaN
# 10                  209.0              4.1                 NaN
# 11                  273.0              4.1                 NaN
# 12                  273.0              0.4                 NaN
# 13                  219.0              0.4                 NaN
# 14                  139.0              0.4                 NaN
# 15                  139.0              0.4                 NaN
# 16                  139.0              0.4                 NaN
# 17                  199.0              0.4                 NaN
# 18                  158.0              0.4                 NaN
# 19                  158.0              0.4                 NaN
# 20                  298.0              0.4                 NaN
# 21                  146.0              0.4                 NaN
# 22                  265.0              0.4                 NaN
# 23                  233.0              0.4                 NaN
# 24                  142.0              0.4                 NaN
# 25                  200.0              NaN                 NaN
# 26                  125.0              NaN                 NaN
# 27                  125.0              0.3                 NaN
# 28                  504.0              0.3                 NaN
# 29                  504.0              0.3                 NaN
# ...                   ...              ...                 ...
# 2010809             154.0              NaN                 NaN
# 2010810             154.0              NaN                 NaN
# 2010811             154.0              NaN                 NaN
# 2010812             154.0              NaN                 NaN
# 2010813             154.0              NaN                 NaN
# 2010814             205.0              NaN                 NaN
# 2010815             202.0              NaN                 NaN
# 2010816             202.0              0.5                 NaN
# 2010817             106.0              0.5                 NaN
# 2010818             106.0              0.5                 NaN
# 2010819             232.0              0.5                 NaN
# 2010820             232.0              0.5                 NaN
# 2010821             196.0              0.5                 NaN
# 2010822             196.0              NaN                 NaN
# 2010823             196.0              NaN                 NaN
# 2010824             129.0              NaN                 NaN
# 2010825             129.0              NaN                 NaN
# 2010826             129.0              NaN                 NaN
# 2010827             185.0              NaN                 NaN
# 2010828             268.0              NaN                 NaN
# 2010829             268.0              0.4                 NaN
# 2010830             268.0              0.4                 NaN
# 2010831             183.0              0.4                 NaN
# 2010832             132.0              0.4                 NaN
# 2010833             158.0              0.4                 NaN
# 2010834             246.0              0.4                 NaN
# 2010835             180.0              NaN                 NaN
# 2010836             161.0              NaN                 NaN
# 2010837             164.0              NaN                 NaN
# 2010838             169.0              NaN                 NaN
#
# [2010839 rows x 7 columns]

# %%
pre_final_lab.describe()
# Out:
#        patientunitstayid  labresultoffset      paO2_FiO2  platelets_x_1000  \
# count       2.010839e+06     2.010839e+06  190301.000000      1.139619e+06
# mean        1.753460e+06     5.185645e+03     388.943193      2.157523e+02
# std         1.003857e+06     3.606784e+04    2225.146286      1.208963e+02
# min         1.411680e+05    -4.731957e+07    -212.500000      0.000000e+00
# 25%         9.594120e+05     1.070000e+02     137.500000      1.370000e+02
# 50%         1.644075e+06     2.125000e+03     214.285720      1.970000e+02
# 75%         2.770721e+06     6.822000e+03     316.666660      2.700000e+02
# max         3.353263e+06     8.305830e+05  129666.664000      3.092000e+03
#
#        total_bilirubin  urinary_creatinine
# count    425009.000000        13227.000000
# mean          1.558249           99.160934
# std           3.586318           71.979411
# min           0.000000            0.400000
# 25%           0.400000           48.000000
# 50%           0.600000           82.840000
# 75%           1.200000          130.555000
# max          99.000000         1288.000000

# %% [markdown]
# <p>The following block is made to iterate over the entire dataset and plug missing values with both ffill and bfill techniques,
# but filling 3 at a time. Due to the code taking a lot of time, I have left it as of now. I'll look into it further after the rest of
# the tables are processed.<p>

# %%
'''while(any(pre_final_lab['paO2_FiO2'].isna()) or any(pre_final_lab['platelets_x_1000'].isna()) or any(pre_final_lab['total_bilirubin'].isna()) or any(pre_final_lab['urinary_creatinine'].isna())):
    pre_final_lab['paO2_FiO2']=pre_final_lab['paO2_FiO2'].ffill(limit=3)
    pre_final_lab['platelets_x_1000']=pre_final_lab['platelets_x_1000'].ffill(limit=3)
    pre_final_lab['total_bilirubin']=pre_final_lab['total_bilirubin'].ffill(limit=3)
    pre_final_lab['urinary_creatinine']=pre_final_lab['urinary_creatinine'].ffill(limit=3)
    pre_final_lab['paO2_FiO2']=pre_final_lab['paO2_FiO2'].bfill(limit=3)
    pre_final_lab['platelets_x_1000']=pre_final_lab['platelets_x_1000'].bfill(limit=3)
    pre_final_lab['total_bilirubin']=pre_final_lab['total_bilirubin'].bfill(limit=3)
    pre_final_lab['urinary_creatinine']=pre_final_lab['urinary_creatinine'].bfill(limit=3)
'''
