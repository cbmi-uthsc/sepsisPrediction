# %%
import pandas as pd
import numpy as np
import csv

# %%
infusiondrug=pd.read_csv("infusionDrug.csv")
infusiondrug.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    infusiondrugid  patientunitstayid  infusionoffset  \
# 0         1953469             242040             457
# 1         1998443             242082             425
# 2         1968206             242082             125
# 3         1991487             242082             665
# 4         1969910             242082              55
#
#                    drugname drugrate  infusionrate  drugamount  volumeoffluid  \
# 0    Milrinone (mcg/kg/min)      .43          11.8        20.0          100.0
# 1  Norepinephrine (mcg/min)    10.93          41.0         4.0          250.0
# 2  Norepinephrine (mcg/min)        7          26.3         4.0          250.0
# 3                NS (ml/hr)      200         200.0         NaN            NaN
# 4  Norepinephrine (mcg/min)     2.13           8.0         4.0          250.0
#
#    patientweight
# 0           91.7
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
infusiondrug.dtypes
# Out:
# infusiondrugid         int64
# patientunitstayid      int64
# infusionoffset         int64
# drugname              object
# drugrate              object
# infusionrate         float64
# drugamount           float64
# volumeoffluid        float64
# patientweight        float64
# dtype: object

# %%
infusiondrug['drugname']=infusiondrug['drugname'].astype('str')

# %%
any(infusiondrug['drugname'].isnull())
# Out:
# False

# %%
drug_names=infusiondrug['drugname'].unique()

# %%
for name in drug_names:
    if("Dobuta" in name):
        print(name)
# Out:
# Dobutamine (mcg/kg/min)
# Dobutamine (mcg/min)
# Dobutamine (ml/hr)
# Dobutamine
# Dobutamine ()
# Dobutamine (mcg/kg/hr)
# Dobutamine (units/min)

# %%
infusiondrug
# Out:
#          infusiondrugid  patientunitstayid  infusionoffset  \
# 0               1953469             242040             457
# 1               1998443             242082             425
# 2               1968206             242082             125
# 3               1991487             242082             665
# 4               1969910             242082              55
# 5               1993002             242082             425
# 6               1965286             242082             230
# 7               1989932             242082            1265
# 8               1966366             242082             275
# 9               1994217             242082             665
# 10              1985898             242082             230
# 11              1963880             242082            1265
# 12              1972141             242082             275
# 13              2007185             242082             125
# 14              1982125             242154            7680
# 15              1968868             242319             301
# 16              1962842             242319              31
# 17              1984512             242325             235
# 18              1976955             242325             235
# 19              1973839             242380             239
# 20              1998894             242380            1379
# 21              1953142             242380              59
# 22              1977744             242380             419
# 23              1951808             242380             239
# 24              2001372             242380             899
# 25              2001050             242380              59
# 26              1965488             242380            1139
# 27              1995720             242380            1379
# 28              1985551             242380             419
# 29              2007060             242380             899
# ...                 ...                ...             ...
# 4803689        75272510            3353251            8773
# 4803690        75271793            3353251            4767
# 4803691        75090899            3353251            1063
# 4803692        75288588            3353251             473
# 4803693        75060387            3353251            3423
# 4803694        75140052            3353251            1843
# 4803695        75307297            3353251            3883
# 4803696        75247564            3353251            7723
# 4803697        75283963            3353251            6823
# 4803698        75048646            3353251             578
# 4803699        75171584            3353251            3943
# 4803700        75087074            3353251            4903
# 4803701        75259537            3353251            1063
# 4803702        75151307            3353251             508
# 4803703        75300278            3353251            5563
# 4803704        75265270            3353251            8503
# 4803705        75089897            3353251            8442
# 4803706        75172067            3353251            7003
# 4803707        75134467            3353251            5623
# 4803708        75217826            3353251            7063
# 4803709        75324276            3353251            4123
# 4803710        75079508            3353251            4173
# 4803711        75183496            3353251            1263
# 4803712        75197021            3353251           11368
# 4803713        75229290            3353251            4183
# 4803714        75192643            3353251            2743
# 4803715        75244146            3353251            2683
# 4803716        75070892            3353251            1303
# 4803717        75161904            3353263             800
# 4803718        75177179            3353263             328
#
#                                                   drugname drugrate  \
# 0                                   Milrinone (mcg/kg/min)      .43
# 1                                 Norepinephrine (mcg/min)    10.93
# 2                                 Norepinephrine (mcg/min)        7
# 3                                               NS (ml/hr)      200
# 4                                 Norepinephrine (mcg/min)     2.13
# 5                                               NS (ml/hr)      200
# 6                                               NS (ml/hr)      200
# 7                                               NS (ml/hr)      200
# 8                                               NS (ml/hr)      200
# 9                                 Norepinephrine (mcg/min)        8
# 10                                Norepinephrine (mcg/min)     9.07
# 11                                Norepinephrine (mcg/min)        3
# 12                                Norepinephrine (mcg/min)       10
# 13                                              NS (ml/hr)      200
# 14                                   Propofol (mcg/kg/min)       15
# 15                                Norepinephrine (mcg/min)        0
# 16                                Norepinephrine (mcg/min)        4
# 17                                      Lidocaine (mg/min)        1
# 18                                      Heparin (units/hr)        0
# 19                                 Nitroglycerin (mcg/min)       20
# 20                                 Nitroglycerin (mcg/min)        0
# 21                                      Heparin (units/hr)     1000
# 22                                 Nitroglycerin (mcg/min)        0
# 23                                      Heparin (units/hr)     1000
# 24                                 Nitroglycerin (mcg/min)        0
# 25                                 Nitroglycerin (mcg/min)       10
# 26                                      Heparin (units/hr)     1300
# 27                                      Heparin (units/hr)        0
# 28                                      Heparin (units/hr)     1000
# 29                                      Heparin (units/hr)     1300
# ...                                                    ...      ...
# 4803689  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      3.8
# 4803690  Vasopressin 40 Units Sodium Chloride 0.9% 100 ...   0.0267
# 4803691  Phenylephrine  MAX 100 mg Sodium Chloride 0.9%...       50
# 4803692  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...     14.4
# 4803693  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      7.6
# 4803694  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       16
# 4803695  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      5.7
# 4803696  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      3.8
# 4803697  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      4.7
# 4803698  Phenylephrine  MAX 100 mg Sodium Chloride 0.9%...      220
# 4803699  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      5.6
# 4803700  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      1.2
# 4803701  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...     14.2
# 4803702  Propofol (Diprivan) 1000 mg  100 ml  Premix (m...       35
# 4803703  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      3.7
# 4803704  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      7.3
# 4803705  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      3.2
# 4803706  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...        5
# 4803707  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      7.7
# 4803708  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...        3
# 4803709  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      4.1
# 4803710  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      2.9
# 4803711  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      4.6
# 4803712  Furosemide (Lasix) STD 250 mg Sodium Chloride ...       10
# 4803713  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      2.3
# 4803714  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      2.5
# 4803715  Insulin 250 Units Sodium Chloride 0.9% 250 ml ...      2.2
# 4803716  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       12
# 4803717  Heparin 25000 Units Dextrose 5% 500 ml  Premix...       19
# 4803718  Heparin 25000 Units Dextrose 5% 500 ml  Premix...       15
#
#          infusionrate  drugamount  volumeoffluid  patientweight
# 0                11.8        20.0          100.0           91.7
# 1                41.0         4.0          250.0            NaN
# 2                26.3         4.0          250.0            NaN
# 3               200.0         NaN            NaN            NaN
# 4                 8.0         4.0          250.0            NaN
# 5               200.0         NaN            NaN            NaN
# 6               200.0         NaN            NaN            NaN
# 7               200.0         NaN            NaN            NaN
# 8               200.0         NaN            NaN            NaN
# 9                30.0         4.0          250.0            NaN
# 10               34.0         4.0          250.0            NaN
# 11               11.3         4.0          250.0            NaN
# 12               37.5         4.0          250.0            NaN
# 13              200.0         NaN            NaN            NaN
# 14                4.8      1000.0          100.0           53.1
# 15                0.0         4.0          250.0            NaN
# 16               15.0         4.0          250.0            NaN
# 17               15.0      1000.0          250.0            NaN
# 18                0.0     25000.0          500.0            NaN
# 19                6.0        50.0          250.0            NaN
# 20                0.0        50.0          250.0            NaN
# 21               20.0     25000.0          500.0            NaN
# 22                0.0        50.0          250.0            NaN
# 23               20.0     25000.0          500.0            NaN
# 24                0.0        50.0          250.0            NaN
# 25                3.0        50.0          250.0            NaN
# 26               26.0     25000.0          500.0            NaN
# 27                0.0     25000.0          500.0            NaN
# 28               20.0     25000.0          500.0            NaN
# 29               26.0     25000.0          500.0            NaN
# ...               ...         ...            ...            ...
# 4803689           NaN         NaN            NaN            NaN
# 4803690           NaN         NaN            NaN            NaN
# 4803691           NaN         NaN            NaN            NaN
# 4803692           NaN         NaN            NaN            NaN
# 4803693           NaN         NaN            NaN            NaN
# 4803694           NaN         NaN            NaN            NaN
# 4803695           NaN         NaN            NaN            NaN
# 4803696           NaN         NaN            NaN            NaN
# 4803697           NaN         NaN            NaN            NaN
# 4803698           NaN         NaN            NaN            NaN
# 4803699           NaN         NaN            NaN            NaN
# 4803700           NaN         NaN            NaN            NaN
# 4803701           NaN         NaN            NaN            NaN
# 4803702           NaN         NaN            NaN            NaN
# 4803703           NaN         NaN            NaN            NaN
# 4803704           NaN         NaN            NaN            NaN
# 4803705           NaN         NaN            NaN            NaN
# 4803706           NaN         NaN            NaN            NaN
# 4803707           NaN         NaN            NaN            NaN
# 4803708           NaN         NaN            NaN            NaN
# 4803709           NaN         NaN            NaN            NaN
# 4803710           NaN         NaN            NaN            NaN
# 4803711           NaN         NaN            NaN            NaN
# 4803712           NaN         NaN            NaN            NaN
# 4803713           NaN         NaN            NaN            NaN
# 4803714           NaN         NaN            NaN            NaN
# 4803715           NaN         NaN            NaN            NaN
# 4803716           NaN         NaN            NaN            NaN
# 4803717           NaN         NaN            NaN            NaN
# 4803718           NaN         NaN            NaN            NaN
#
# [4803719 rows x 9 columns]

# %%
inf_drug=infusiondrug.loc[(infusiondrug['drugname'].str.contains("Dopamine")) | 
                              (infusiondrug['drugname'].str.contains("Norepinephrine")) | 
                              (infusiondrug['drugname'].str.contains("Epinephrine")) | 
                               (infusiondrug['drugname'].str.contains("norepinephrine")) | 
                               (infusiondrug['drugname'].str.contains("dopamine")) | 
                              (infusiondrug['drugname'].str.contains("Dobutamine"))]

# %%
#infusiondrug.to_csv("cardiovascular_params.csv", sep=',', index=False, encoding='utf-8')

# %% [markdown]
# <h1>Continue from here</h1>

# %%
#inf_drug=pd.read_csv('cardiovascular_params.csv')

# %%
inf_drug_new=inf_drug.loc[inf_drug['drugname'].str.contains("\(")]

# %%
inf_drug_new['unit']=""
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
inf_drug_new['unit']=inf_drug_new['drugname'].apply(lambda x: x.split('(')[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
inf_drug_new['drugname'].unique()
# Out:
# array(['Norepinephrine (mcg/min)', 'Dopamine (mcg/kg/min)',
#        'Epinephrine (mcg/min)', 'Norepinephrine (ml/hr)',
#        'Norepinephrine ()', 'Dopamine (ml/hr)', 'Dobutamine (mcg/kg/min)',
#        'Norepinephrine (Unknown)', 'Norepinephrine (mcg/hr)',
#        'Norepinephrine (mcg/kg/min)', 'Norepinephrine (mg/hr)',
#        'Epinephrine (mcg/kg/min)', 'Epinephrine (ml/hr)',
#        'Norepinephrine (mcg/kg/hr)', 'Norepinephrine (mg/min)',
#        'Dobutamine (mcg/min)', 'Epinephrine (mcg/hr)', 'Dopamine ()',
#        'Dobutamine (ml/hr)', 'Dopamine (mcg/min)',
#        'dopamine (mcg/kg/min)', 'Epinephrine (mg/hr)',
#        'Epinephrine (mg/kg/min)', 'Dopamine (mcg/hr)',
#        'Norepinephrine (units/min)', 'Dobutamine ()',
#        'Dobutamine (mcg/kg/hr)', 'Dopamine (mg/hr)', 'Dopamine (Unknown)',
#        'Epinephrine ()', 'Dopamine (mcg/kg/hr)',
#        'Norepinephrine (mg/kg/min)', 'Dopamine (nanograms/kg/min)',
#        'norepinephrine Volume (ml) (ml/hr)', 'norepinephrine Volume (ml)',
#        'Dobutamine (units/min)',
#        'Norepinephrine STD 4 mg Dextrose 5% 250 ml (mcg/min)',
#        'Norepinephrine MAX 32 mg Dextrose 5% 250 ml (mcg/min)',
#        'Norepinephrine STD 8 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine STD 32 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine STD 4 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine MAX 32 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine STD 32 mg Dextrose 5% 282 ml (mcg/min)',
#        'Norepinephrine STD 8 mg Dextrose 5% 250 ml (mcg/min)'],
#       dtype=object)

# %%
inf_drug_filtered=inf_drug_new.loc[(inf_drug_new['unit'].str.contains("mcg/min")) | (inf_drug_new['unit'].str.contains("mcg/kg/min")) |
                (inf_drug_new['unit'].str.contains("mcg/hr")) | (inf_drug_new['unit'].str.contains("mg/hr")) |
                (inf_drug_new['unit'].str.contains("mcg/kg/hr")) | (inf_drug_new['unit'].str.contains("mg/min")) |
                (inf_drug_new['unit'].str.contains("mg/kg/min")) | (inf_drug_new['unit'].str.contains("nanograms/kg/min"))]

# %%
len(inf_drug_filtered)
# Out:
# 337283

# %% [markdown]
# <h2>Now we begin to change the units to a uniform mcg/min or mcg/kg/min</h2>

# %%
floats=[]
index=0
for value in inf_drug_filtered['drugrate']:
    index+=1
    try:
        x=float(value)
    except ValueError as e:
        print("error",e,"on line",index)
# Out:
# error could not convert string to float: 'OFF\\.br\\\\.br\\' on line 320429
# error could not convert string to float: '30\\.br\\' on line 320970
# error could not convert string to float: '50 mcg/min' on line 322544
# error could not convert string to float: '50mcg/min\\.br\\' on line 322557
# error could not convert string to float: 'OFF' on line 322915
# error could not convert string to float: 'OFF' on line 322916
# error could not convert string to float: 'OFF' on line 322925
# error could not convert string to float: 'OFF' on line 329343
# error could not convert string to float: 'OFF' on line 329363
# error could not convert string to float: 'Documentation undone' on line 329443

# %% [markdown]
# <h4>Delete these lines - in the above lines</h4>

# %%
inf_drug_filtered=inf_drug_filtered.loc[~(inf_drug_filtered['drugrate']=='OFF\\.br\\\\.br\\') & ~(inf_drug_filtered['drugrate']=='30\\.br\\') &
                     ~(inf_drug_filtered['drugrate']=='50 mcg/min') & ~(inf_drug_filtered['drugrate']=='50mcg/min\\.br\\') &
                     ~(inf_drug_filtered['drugrate']=='OFF') & ~(inf_drug_filtered['drugrate']=='Documentation undone')]

# %%
inf_drug_filtered[['drugrate']]=inf_drug_filtered[['drugrate']].astype(str).astype(float)

# %% [markdown]
# <h4>Convert milli, nano to micro and hr to min</h4>

# %%
inf_drug_filtered.loc[inf_drug_filtered['unit'].str.contains("mg/hr"),'drugrate']=inf_drug_filtered['drugrate']*(100/6)
inf_drug_filtered.loc[inf_drug_filtered['unit'].str.contains("mcg/hr"),'drugrate']=inf_drug_filtered['drugrate']*(1/60)
inf_drug_filtered.loc[inf_drug_filtered['unit'].str.contains("mcg/kg/hr"),'drugrate']=inf_drug_filtered['drugrate']*(1/60)
inf_drug_filtered.loc[inf_drug_filtered['unit'].str.contains("mg/min"),'drugrate']=inf_drug_filtered['drugrate']*(1000)
inf_drug_filtered.loc[inf_drug_filtered['unit'].str.contains("mg/kg/min"),'drugrate']=inf_drug_filtered['drugrate']*(1000)
inf_drug_filtered.loc[inf_drug_filtered['unit'].str.contains("nanograms/kg/min"),'drugrate']=inf_drug_filtered['drugrate']*(1/1000)

# %%
inf_drug_filtered['unit']=inf_drug_filtered['unit'].replace(['mg/hr)','mcg/hr)','mg/min)','mcg/min)'],'mcg/min')

# %%
inf_drug_filtered['unit']=inf_drug_filtered['unit'].replace(['mcg/kg/hr)','mg/kg/min)','nanograms/kg/min)','mcg/kg/min)'],'mcg/kg/min')

# %% [markdown]
# <h4>Now, the only remaining thing to do to this table is adjust the drugrate with the patient weight from the patient.csv table</h4>

# %%
inf_drug_pre_patient=inf_drug_filtered

# %%
inf_drug_pre_patient.head()
# Out:
#     infusiondrugid  patientunitstayid  infusionoffset  \
# 1          1998443             242082             425
# 2          1968206             242082             125
# 4          1969910             242082              55
# 9          1994217             242082             665
# 10         1985898             242082             230
#
#                     drugname  drugrate  infusionrate  drugamount  \
# 1   Norepinephrine (mcg/min)     10.93          41.0         4.0
# 2   Norepinephrine (mcg/min)      7.00          26.3         4.0
# 4   Norepinephrine (mcg/min)      2.13           8.0         4.0
# 9   Norepinephrine (mcg/min)      8.00          30.0         4.0
# 10  Norepinephrine (mcg/min)      9.07          34.0         4.0
#
#     volumeoffluid  patientweight     unit
# 1           250.0            NaN  mcg/min
# 2           250.0            NaN  mcg/min
# 4           250.0            NaN  mcg/min
# 9           250.0            NaN  mcg/min
# 10          250.0            NaN  mcg/min

# %%
patient=pd.read_csv('patient.csv', usecols=['patientunitstayid', 'admissionweight', 'dischargeweight', 'unitdischargeoffset'])

# %%
patient.head()
# Out:
#    patientunitstayid  admissionweight  dischargeweight  unitdischargeoffset
# 0             141168             84.3             85.8                 3596
# 1             141178             54.4             54.4                    8
# 2             141179              NaN             60.4                 2042
# 3             141194             73.9             76.7                 4813
# 4             141196              NaN             63.2                 1463

# %% [markdown]
# <h4>Since we will be updating the table with admission and discharge weights from the patient table,
#     we can delete the patientweight column from the infusiondrug table</h4>

# %%
inf_drug_pre_patient['admissionweight']=np.nan
inf_drug_pre_patient['dischargeweight']=np.nan

# %%
len(patient['patientunitstayid'].unique())
# Out:
# 200859

# %%
len(inf_drug_pre_patient['patientunitstayid'].unique())
# Out:
# 9924

# %%
patient.loc[patient['patientunitstayid']==242082,'admissionweight'].values[0]
# Out:
# 90.7

# %%
for pid in inf_drug_pre_patient['patientunitstayid'].unique():
    inf_drug_pre_patient.loc[inf_drug_pre_patient['patientunitstayid']==pid,'admissionweight']=patient.loc[patient['patientunitstayid']==pid,'admissionweight'].values[0]
    inf_drug_pre_patient.loc[inf_drug_pre_patient['patientunitstayid']==pid,'dischargeweight']=patient.loc[patient['patientunitstayid']==pid,'dischargeweight'].values[0]

# %%
#save an additional copy before the normailzation stage
inf_drug_pre_patient.to_csv("cardiovascular_params.csv", sep=',', index=False, encoding='utf-8')

# %%
inf_drug_pre_patient.loc[inf_drug_pre_patient['admissionweight']==0]
# Out:
#          infusiondrugid  patientunitstayid  infusionoffset  \
# 4671953        72750321            3158852              78
# 4671954        72603425            3158852            2328
# 4671957        72486302            3158852             708
# 4671960        72771339            3158852             948
# 4671969        72486314            3158852            2148
# 4671974        72284325            3158852             888
# 4671976        72215915            3158852            2388
# 4671979        72833613            3158852             828
# 4671988        72385970            3158852            2268
# 4671989        72199284            3158852            1548
# 4671992        72745447            3158852             288
# 4671993        72746271            3158852            1068
# 4671995        72544351            3158852            1488
# 4672007        72590739            3158852             108
# 4672012        72374142            3158852            2208
# 4672027        72320786            3158852             768
# 4672029        72510433            3158852            1008
# 4672036        72729343            3158852             648
# 4672039        72716230            3158852              18
# 4672041        72513670            3158852            1728
# 4672044        72800487            3158852            2088
# 4672045        72657465            3158852             348
# 4672046        72846079            3158852            1128
# 4672051        72222334            3158852              93
# 4672059        72280158            3158852            1428
# 4672060        72647819            3158852            1848
# 4672064        72218648            3158852             408
# 4672068        72586688            3158852            1908
# 4672069        72367029            3158852            1788
# 4672070        72363218            3158852            2568
# 4672074        72453147            3158852            1248
# 4672086        72436277            3158852            2748
# 4672089        72337361            3158852            1383
# 4672094        72749051            3158852            1188
# 4672096        72500363            3158852             468
# 4672097        72789280            3158852            2688
# 4672099        72806927            3158852            2508
# 4672101        72816985            3158852             588
# 4672115        72275355            3158852            2448
# 4672117        72761442            3158852            1308
# 4672123        72770627            3158852            2028
# 4672132        72677084            3158852            1668
# 4672134        72442854            3158852             228
# 4672136        72472979            3158852             168
# 4672138        72649825            3158852            1608
# 4672141        72735641            3158852            1968
# 4672152        72198875            3158852             528
# 4729692        74725836            3227612              91
# 4729694        74480497            3227612              91
# 4729695        74326987            3227612              91
#
#                          drugname  drugrate  infusionrate  drugamount  \
# 4671953  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671954  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671957  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4671960  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671969  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4671974  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671976  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671979  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671988  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4671989  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4671992  Norepinephrine (mcg/min)      20.0          37.5         8.0
# 4671993  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4671995  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672007  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672012  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672027  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672029  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4672036  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672039  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672041  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672044  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672045  Norepinephrine (mcg/min)      15.0          28.1         8.0
# 4672046  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4672051  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4672059  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4672060  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672064  Norepinephrine (mcg/min)      10.0          18.8         8.0
# 4672068  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672069  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672070  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672074  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4672086  Norepinephrine (mcg/min)       1.0           1.9         8.0
# 4672089  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4672094  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4672096  Norepinephrine (mcg/min)      10.0          18.8         8.0
# 4672097  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672099  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4672101  Norepinephrine (mcg/min)       8.0          15.0         8.0
# 4672115  Norepinephrine (mcg/min)       3.0           5.6         8.0
# 4672117  Norepinephrine (mcg/min)       4.0           7.5         8.0
# 4672123  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672132  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672134  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672136  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672138  Norepinephrine (mcg/min)       2.0           3.8         8.0
# 4672141  Norepinephrine (mcg/min)       5.0           9.4         8.0
# 4672152  Norepinephrine (mcg/min)       8.0          15.0         8.0
# 4729692     Dopamine (mcg/kg/min)      20.0           0.0       400.0
# 4729694  Norepinephrine (mcg/min)     160.0         600.0         4.0
# 4729695  Epinephrine (mcg/kg/min)     999.0           0.0         4.0
#
#          volumeoffluid  patientweight        unit  admissionweight  \
# 4671953          250.0            NaN     mcg/min              0.0
# 4671954          250.0            NaN     mcg/min              0.0
# 4671957          250.0            NaN     mcg/min              0.0
# 4671960          250.0            NaN     mcg/min              0.0
# 4671969          250.0            NaN     mcg/min              0.0
# 4671974          250.0            NaN     mcg/min              0.0
# 4671976          250.0            NaN     mcg/min              0.0
# 4671979          250.0            NaN     mcg/min              0.0
# 4671988          250.0            NaN     mcg/min              0.0
# 4671989          250.0            NaN     mcg/min              0.0
# 4671992          250.0            NaN     mcg/min              0.0
# 4671993          250.0            NaN     mcg/min              0.0
# 4671995          250.0            NaN     mcg/min              0.0
# 4672007          250.0            NaN     mcg/min              0.0
# 4672012          250.0            NaN     mcg/min              0.0
# 4672027          250.0            NaN     mcg/min              0.0
# 4672029          250.0            NaN     mcg/min              0.0
# 4672036          250.0            NaN     mcg/min              0.0
# 4672039          250.0            NaN     mcg/min              0.0
# 4672041          250.0            NaN     mcg/min              0.0
# 4672044          250.0            NaN     mcg/min              0.0
# 4672045          250.0            NaN     mcg/min              0.0
# 4672046          250.0            NaN     mcg/min              0.0
# 4672051          250.0            NaN     mcg/min              0.0
# 4672059          250.0            NaN     mcg/min              0.0
# 4672060          250.0            NaN     mcg/min              0.0
# 4672064          250.0            NaN     mcg/min              0.0
# 4672068          250.0            NaN     mcg/min              0.0
# 4672069          250.0            NaN     mcg/min              0.0
# 4672070          250.0            NaN     mcg/min              0.0
# 4672074          250.0            NaN     mcg/min              0.0
# 4672086          250.0            NaN     mcg/min              0.0
# 4672089          250.0            NaN     mcg/min              0.0
# 4672094          250.0            NaN     mcg/min              0.0
# 4672096          250.0            NaN     mcg/min              0.0
# 4672097          250.0            NaN     mcg/min              0.0
# 4672099          250.0            NaN     mcg/min              0.0
# 4672101          250.0            NaN     mcg/min              0.0
# 4672115          250.0            NaN     mcg/min              0.0
# 4672117          250.0            NaN     mcg/min              0.0
# 4672123          250.0            NaN     mcg/min              0.0
# 4672132          250.0            NaN     mcg/min              0.0
# 4672134          250.0            NaN     mcg/min              0.0
# 4672136          250.0            NaN     mcg/min              0.0
# 4672138          250.0            NaN     mcg/min              0.0
# 4672141          250.0            NaN     mcg/min              0.0
# 4672152          250.0            NaN     mcg/min              0.0
# 4729692          250.0            0.0  mcg/kg/min              0.0
# 4729694          250.0            NaN     mcg/min              0.0
# 4729695          250.0            0.0  mcg/kg/min              0.0
#
#          dischargeweight
# 4671953              NaN
# 4671954              NaN
# 4671957              NaN
# 4671960              NaN
# 4671969              NaN
# 4671974              NaN
# 4671976              NaN
# 4671979              NaN
# 4671988              NaN
# 4671989              NaN
# 4671992              NaN
# 4671993              NaN
# 4671995              NaN
# 4672007              NaN
# 4672012              NaN
# 4672027              NaN
# 4672029              NaN
# 4672036              NaN
# 4672039              NaN
# 4672041              NaN
# 4672044              NaN
# 4672045              NaN
# 4672046              NaN
# 4672051              NaN
# 4672059              NaN
# 4672060              NaN
# 4672064              NaN
# 4672068              NaN
# 4672069              NaN
# 4672070              NaN
# 4672074              NaN
# 4672086              NaN
# 4672089              NaN
# 4672094              NaN
# 4672096              NaN
# 4672097              NaN
# 4672099              NaN
# 4672101              NaN
# 4672115              NaN
# 4672117              NaN
# 4672123              NaN
# 4672132              NaN
# 4672134              NaN
# 4672136              NaN
# 4672138              NaN
# 4672141              NaN
# 4672152              NaN
# 4729692              NaN
# 4729694              NaN
# 4729695              NaN

# %% [markdown]
# <h4>As we can see, the records where admissionweight is 0, the discharge weight is also NaN. This means, we either omit these
#     records, or fill the holes with a mean value. Since such records are very less as compared to entire dataset, we can fill them with their means. It won't skew the data much</h4>

# %%
inf_drug_pre_patient['admissionweight']=inf_drug_pre_patient['admissionweight'].fillna(inf_drug_pre_patient['admissionweight'].mean())
inf_drug_pre_patient['dischargeweight']=inf_drug_pre_patient['dischargeweight'].fillna(inf_drug_pre_patient['dischargeweight'].mean())

# %% [markdown]
# <h4>To avoid division by zero error, we will change the 0s for dischargeweight as 1</h4>

# %%
inf_drug_pre_patient['dischargeweight']=inf_drug_pre_patient['dischargeweight'].replace([0,0.0],1)

# %%
any(inf_drug_pre_patient['dischargeweight'].isna())
# Out:
# False

# %%
inf_drug_pre_patient.loc[((inf_drug_pre_patient['admissionweight']==np.nan) | (inf_drug_pre_patient['admissionweight']==0)) & 
                         (inf_drug_pre_patient['unit']=='mcg/min'),'drugrate']=inf_drug_pre_patient.loc[((inf_drug_pre_patient['admissionweight']==np.nan) | 
                          (inf_drug_pre_patient['admissionweight']==0)) & (inf_drug_pre_patient['unit']=='mcg/min')].apply(lambda x : (x['drugrate']/x['dischargeweight']),axis=1)

# %%
inf_drug_pre_patient.loc[inf_drug_pre_patient['admissionweight']==0]
# Out:
#          infusiondrugid  patientunitstayid  infusionoffset  \
# 4671953        72750321            3158852              78
# 4671954        72603425            3158852            2328
# 4671957        72486302            3158852             708
# 4671960        72771339            3158852             948
# 4671969        72486314            3158852            2148
# 4671974        72284325            3158852             888
# 4671976        72215915            3158852            2388
# 4671979        72833613            3158852             828
# 4671988        72385970            3158852            2268
# 4671989        72199284            3158852            1548
# 4671992        72745447            3158852             288
# 4671993        72746271            3158852            1068
# 4671995        72544351            3158852            1488
# 4672007        72590739            3158852             108
# 4672012        72374142            3158852            2208
# 4672027        72320786            3158852             768
# 4672029        72510433            3158852            1008
# 4672036        72729343            3158852             648
# 4672039        72716230            3158852              18
# 4672041        72513670            3158852            1728
# 4672044        72800487            3158852            2088
# 4672045        72657465            3158852             348
# 4672046        72846079            3158852            1128
# 4672051        72222334            3158852              93
# 4672059        72280158            3158852            1428
# 4672060        72647819            3158852            1848
# 4672064        72218648            3158852             408
# 4672068        72586688            3158852            1908
# 4672069        72367029            3158852            1788
# 4672070        72363218            3158852            2568
# 4672074        72453147            3158852            1248
# 4672086        72436277            3158852            2748
# 4672089        72337361            3158852            1383
# 4672094        72749051            3158852            1188
# 4672096        72500363            3158852             468
# 4672097        72789280            3158852            2688
# 4672099        72806927            3158852            2508
# 4672101        72816985            3158852             588
# 4672115        72275355            3158852            2448
# 4672117        72761442            3158852            1308
# 4672123        72770627            3158852            2028
# 4672132        72677084            3158852            1668
# 4672134        72442854            3158852             228
# 4672136        72472979            3158852             168
# 4672138        72649825            3158852            1608
# 4672141        72735641            3158852            1968
# 4672152        72198875            3158852             528
# 4729692        74725836            3227612              91
# 4729694        74480497            3227612              91
# 4729695        74326987            3227612              91
#
#                          drugname    drugrate  infusionrate  drugamount  \
# 4671953  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671954  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671957  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4671960  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671969  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4671974  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671976  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671979  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671988  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4671989  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4671992  Norepinephrine (mcg/min)    0.228519          37.5         8.0
# 4671993  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4671995  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672007  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672012  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672027  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672029  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4672036  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672039  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672041  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672044  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672045  Norepinephrine (mcg/min)    0.171389          28.1         8.0
# 4672046  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4672051  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4672059  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4672060  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672064  Norepinephrine (mcg/min)    0.114260          18.8         8.0
# 4672068  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672069  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672070  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672074  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4672086  Norepinephrine (mcg/min)    0.011426           1.9         8.0
# 4672089  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4672094  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4672096  Norepinephrine (mcg/min)    0.114260          18.8         8.0
# 4672097  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672099  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4672101  Norepinephrine (mcg/min)    0.091408          15.0         8.0
# 4672115  Norepinephrine (mcg/min)    0.034278           5.6         8.0
# 4672117  Norepinephrine (mcg/min)    0.045704           7.5         8.0
# 4672123  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672132  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672134  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672136  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672138  Norepinephrine (mcg/min)    0.022852           3.8         8.0
# 4672141  Norepinephrine (mcg/min)    0.057130           9.4         8.0
# 4672152  Norepinephrine (mcg/min)    0.091408          15.0         8.0
# 4729692     Dopamine (mcg/kg/min)   20.000000           0.0       400.0
# 4729694  Norepinephrine (mcg/min)    1.828152         600.0         4.0
# 4729695  Epinephrine (mcg/kg/min)  999.000000           0.0         4.0
#
#          volumeoffluid  patientweight        unit  admissionweight  \
# 4671953          250.0            NaN     mcg/min              0.0
# 4671954          250.0            NaN     mcg/min              0.0
# 4671957          250.0            NaN     mcg/min              0.0
# 4671960          250.0            NaN     mcg/min              0.0
# 4671969          250.0            NaN     mcg/min              0.0
# 4671974          250.0            NaN     mcg/min              0.0
# 4671976          250.0            NaN     mcg/min              0.0
# 4671979          250.0            NaN     mcg/min              0.0
# 4671988          250.0            NaN     mcg/min              0.0
# 4671989          250.0            NaN     mcg/min              0.0
# 4671992          250.0            NaN     mcg/min              0.0
# 4671993          250.0            NaN     mcg/min              0.0
# 4671995          250.0            NaN     mcg/min              0.0
# 4672007          250.0            NaN     mcg/min              0.0
# 4672012          250.0            NaN     mcg/min              0.0
# 4672027          250.0            NaN     mcg/min              0.0
# 4672029          250.0            NaN     mcg/min              0.0
# 4672036          250.0            NaN     mcg/min              0.0
# 4672039          250.0            NaN     mcg/min              0.0
# 4672041          250.0            NaN     mcg/min              0.0
# 4672044          250.0            NaN     mcg/min              0.0
# 4672045          250.0            NaN     mcg/min              0.0
# 4672046          250.0            NaN     mcg/min              0.0
# 4672051          250.0            NaN     mcg/min              0.0
# 4672059          250.0            NaN     mcg/min              0.0
# 4672060          250.0            NaN     mcg/min              0.0
# 4672064          250.0            NaN     mcg/min              0.0
# 4672068          250.0            NaN     mcg/min              0.0
# 4672069          250.0            NaN     mcg/min              0.0
# 4672070          250.0            NaN     mcg/min              0.0
# 4672074          250.0            NaN     mcg/min              0.0
# 4672086          250.0            NaN     mcg/min              0.0
# 4672089          250.0            NaN     mcg/min              0.0
# 4672094          250.0            NaN     mcg/min              0.0
# 4672096          250.0            NaN     mcg/min              0.0
# 4672097          250.0            NaN     mcg/min              0.0
# 4672099          250.0            NaN     mcg/min              0.0
# 4672101          250.0            NaN     mcg/min              0.0
# 4672115          250.0            NaN     mcg/min              0.0
# 4672117          250.0            NaN     mcg/min              0.0
# 4672123          250.0            NaN     mcg/min              0.0
# 4672132          250.0            NaN     mcg/min              0.0
# 4672134          250.0            NaN     mcg/min              0.0
# 4672136          250.0            NaN     mcg/min              0.0
# 4672138          250.0            NaN     mcg/min              0.0
# 4672141          250.0            NaN     mcg/min              0.0
# 4672152          250.0            NaN     mcg/min              0.0
# 4729692          250.0            0.0  mcg/kg/min              0.0
# 4729694          250.0            NaN     mcg/min              0.0
# 4729695          250.0            0.0  mcg/kg/min              0.0
#
#          dischargeweight
# 4671953        87.520066
# 4671954        87.520066
# 4671957        87.520066
# 4671960        87.520066
# 4671969        87.520066
# 4671974        87.520066
# 4671976        87.520066
# 4671979        87.520066
# 4671988        87.520066
# 4671989        87.520066
# 4671992        87.520066
# 4671993        87.520066
# 4671995        87.520066
# 4672007        87.520066
# 4672012        87.520066
# 4672027        87.520066
# 4672029        87.520066
# 4672036        87.520066
# 4672039        87.520066
# 4672041        87.520066
# 4672044        87.520066
# 4672045        87.520066
# 4672046        87.520066
# 4672051        87.520066
# 4672059        87.520066
# 4672060        87.520066
# 4672064        87.520066
# 4672068        87.520066
# 4672069        87.520066
# 4672070        87.520066
# 4672074        87.520066
# 4672086        87.520066
# 4672089        87.520066
# 4672094        87.520066
# 4672096        87.520066
# 4672097        87.520066
# 4672099        87.520066
# 4672101        87.520066
# 4672115        87.520066
# 4672117        87.520066
# 4672123        87.520066
# 4672132        87.520066
# 4672134        87.520066
# 4672136        87.520066
# 4672138        87.520066
# 4672141        87.520066
# 4672152        87.520066
# 4729692        87.520066
# 4729694        87.520066
# 4729695        87.520066

# %%
inf_drug_pre_patient.loc[(inf_drug_pre_patient['admissionweight']>0) & 
                         (inf_drug_pre_patient['unit']=='mcg/min'),'drugrate']=inf_drug_pre_patient.loc[(inf_drug_pre_patient['admissionweight']>0) & 
                                                                                                        (inf_drug_pre_patient['unit']=='mcg/min')].apply(lambda x : (x['drugrate']/x['admissionweight']),axis=1)

# %%
inf_drug_pre_patient.head()
# Out:
#     infusiondrugid  patientunitstayid  infusionoffset  \
# 1          1998443             242082             425
# 2          1968206             242082             125
# 4          1969910             242082              55
# 9          1994217             242082             665
# 10         1985898             242082             230
#
#                     drugname  drugrate  infusionrate  drugamount  \
# 1   Norepinephrine (mcg/min)  0.120507          41.0         4.0
# 2   Norepinephrine (mcg/min)  0.077178          26.3         4.0
# 4   Norepinephrine (mcg/min)  0.023484           8.0         4.0
# 9   Norepinephrine (mcg/min)  0.088203          30.0         4.0
# 10  Norepinephrine (mcg/min)  0.100000          34.0         4.0
#
#     volumeoffluid  patientweight     unit  admissionweight  dischargeweight
# 1           250.0            NaN  mcg/min             90.7            104.3
# 2           250.0            NaN  mcg/min             90.7            104.3
# 4           250.0            NaN  mcg/min             90.7            104.3
# 9           250.0            NaN  mcg/min             90.7            104.3
# 10          250.0            NaN  mcg/min             90.7            104.3

# %% [markdown]
# <h4>We will need to add MAP data as well</h4>

# %%
#adding explicit drug columns 
inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname'].str.contains('Norepi', case=True, regex=False),'drugname']='Norepinephrine'
inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname'].str.contains('Epi', case=True, regex=False),'drugname']='Epinephrine'
inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname'].str.contains('Dopa', case=False, regex=False),'drugname']='Dopamine'
inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname'].str.contains('Dobuta', case=True, regex=False),'drugname']='Dobutamine'

# %%
#create columns
inf_drug_pre_patient['Norepinephrine']=np.nan
inf_drug_pre_patient['Epinephrine']=np.nan
inf_drug_pre_patient['Dopamine']=np.nan
inf_drug_pre_patient['Dobutamine']=np.nan

# %%
#Feed the values from drugrate
inf_drug_pre_patient['Norepinephrine']=inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname']=='Norepinephrine','drugrate']
inf_drug_pre_patient['Epinephrine']=inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname']=='Epinephrine','drugrate']
inf_drug_pre_patient['Dopamine']=inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname']=='Dopamine','drugrate']
inf_drug_pre_patient['Dobutamine']=inf_drug_pre_patient.loc[inf_drug_pre_patient['drugname']=='Dobutamine','drugrate']

# %%
del inf_drug_pre_patient['infusiondrugid']
del inf_drug_pre_patient['drugname']

# %%
inf_drug_pre_patient.head()
# Out:
#    patientunitstayid  infusionoffset  drugrate  infusionrate  drugamount  \
# 0             242082             425  0.120507          41.0         4.0
# 1             242082             125  0.077178          26.3         4.0
# 2             242082              55  0.023484           8.0         4.0
# 3             242082             665  0.088203          30.0         4.0
# 4             242082             230  0.100000          34.0         4.0
#
#    volumeoffluid  patientweight     unit  admissionweight  dischargeweight  \
# 0          250.0            NaN  mcg/min             90.7            104.3
# 1          250.0            NaN  mcg/min             90.7            104.3
# 2          250.0            NaN  mcg/min             90.7            104.3
# 3          250.0            NaN  mcg/min             90.7            104.3
# 4          250.0            NaN  mcg/min             90.7            104.3
#
#    Norepinephrine  Epinephrine  Dopamine  Dobutamine
# 0        0.120507          NaN       NaN         NaN
# 1        0.077178          NaN       NaN         NaN
# 2        0.023484          NaN       NaN         NaN
# 3        0.088203          NaN       NaN         NaN
# 4        0.100000          NaN       NaN         NaN

# %%
del inf_drug_pre_patient['infusionrate']
del inf_drug_pre_patient['drugamount']

# %%
inf_drug_pre_patient.to_csv("drugrate_norm.csv", sep=',', index=False, encoding='utf-8')

# %%
drugrate_updated=pd.read_csv("drugrate_norm.csv")

# %%
columns=['patientunitstayid','infusionoffset','Norepinephrine','Epinephrine','Dopamine','Dobutamine']
drugrate_updated=drugrate_updated[columns]

# %%
drugrate_updated.head()
# Out:
#    patientunitstayid  infusionoffset  Norepinephrine  Epinephrine  Dopamine  \
# 0             242082             425        0.120507          NaN       NaN
# 1             242082             125        0.077178          NaN       NaN
# 2             242082              55        0.023484          NaN       NaN
# 3             242082             665        0.088203          NaN       NaN
# 4             242082             230        0.100000          NaN       NaN
#
#    Dobutamine
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
nursemap=pd.read_csv("nursechartMAP.csv")

# %%
nursemap.head()
# Out:
#    patientunitstayid  nursingchartentryoffset  \
# 0             141924                     1489
# 1             141924                     1224
# 2             141924                     1564
# 3             141924                      994
# 4             141924                     4144
#
#            nursingchartcelltypecat nursingchartcelltypevallabel  \
# 0  Other Vital Signs and Infusions                   MAP (mmHg)
# 1  Other Vital Signs and Infusions                   MAP (mmHg)
# 2  Other Vital Signs and Infusions                   MAP (mmHg)
# 3  Other Vital Signs and Infusions                   MAP (mmHg)
# 4  Other Vital Signs and Infusions                   MAP (mmHg)
#
#    nursingchartvalue
# 0                 71
# 1                 79
# 2                 73
# 3                 96
# 4                 78

# %%
nursemap=nursemap[['patientunitstayid','nursingchartentryoffset','nursingchartvalue']]

# %%
#since we need both the cardio params as well as the MAP values individually, we will use outer join
df_cardiovascular=pd.merge(drugrate_updated,nursemap,left_on=['patientunitstayid'],right_on=['patientunitstayid'],how='outer').drop_duplicates()

# %%
df_cardiovascular.head()
# Out:
#    patientunitstayid  infusionoffset  Norepinephrine  Epinephrine  Dopamine  \
# 0             242082           425.0        0.120507          NaN       NaN
# 1             242082           125.0        0.077178          NaN       NaN
# 2             242082            55.0        0.023484          NaN       NaN
# 3             242082           665.0        0.088203          NaN       NaN
# 4             242082           230.0        0.100000          NaN       NaN
#
#    Dobutamine  nursingchartentryoffset  nursingchartvalue
# 0         NaN                      NaN                NaN
# 1         NaN                      NaN                NaN
# 2         NaN                      NaN                NaN
# 3         NaN                      NaN                NaN
# 4         NaN                      NaN                NaN

# %%
df_cardiovascular.loc[((df_cardiovascular['Dopamine'] >15)) | ((df_cardiovascular['Epinephrine'] >0.1)) | ((df_cardiovascular['Norepinephrine'] >0.1)), 'SOFA_cardio'] = 4
df_cardiovascular.loc[((df_cardiovascular['Dopamine'] <15)) | ((df_cardiovascular['Epinephrine'] <=0.1)) | ((df_cardiovascular['Norepinephrine'] <=0.1)), 'SOFA_cardio'] = 3
df_cardiovascular.loc[((df_cardiovascular['Dopamine'] <5)) | ((df_cardiovascular['Dobutamine'] >0)), 'SOFA_cardio'] = 2
df_cardiovascular.loc[df_cardiovascular['nursingchartvalue']<70,['SOFA_cardio']]=1
df_cardiovascular.loc[df_cardiovascular['nursingchartvalue']>71,['SOFA_cardio']]=0

# %%
#Now we need to combine these 2 timeoffsets into a single offset
df_cardiovascular['offset'] = np.where(df_cardiovascular['infusionoffset']>0, df_cardiovascular['infusionoffset'], df_cardiovascular['nursingchartentryoffset'])

# %%
df_cardiovascular = df_cardiovascular.dropna(subset = ['offset'])

# %%
len(df_cardiovascular)
# Out:
# 960205

# %%
del df_cardiovascular['infusionoffset']
del df_cardiovascular['nursingchartentryoffset']

# %%
df_cardiovascular.head()
# Out:
#    patientunitstayid  Norepinephrine  Epinephrine  Dopamine  Dobutamine  \
# 0             242082        0.120507          NaN       NaN         NaN
# 1             242082        0.077178          NaN       NaN         NaN
# 2             242082        0.023484          NaN       NaN         NaN
# 3             242082        0.088203          NaN       NaN         NaN
# 4             242082        0.100000          NaN       NaN         NaN
#
#    nursingchartvalue  SOFA_cardio  offset
# 0                NaN          4.0   425.0
# 1                NaN          3.0   125.0
# 2                NaN          3.0    55.0
# 3                NaN          3.0   665.0
# 4                NaN          3.0   230.0

# %%
df_cardiovascular['offset']=df_cardiovascular['offset'].astype('int32')

# %%
df_cardiovascular.head()
# Out:
#    patientunitstayid  Norepinephrine  Epinephrine  Dopamine  Dobutamine  \
# 0             242082        0.120507          NaN       NaN         NaN
# 1             242082        0.077178          NaN       NaN         NaN
# 2             242082        0.023484          NaN       NaN         NaN
# 3             242082        0.088203          NaN       NaN         NaN
# 4             242082        0.100000          NaN       NaN         NaN
#
#    nursingchartvalue  SOFA_cardio  offset
# 0                NaN          4.0     425
# 1                NaN          3.0     125
# 2                NaN          3.0      55
# 3                NaN          3.0     665
# 4                NaN          3.0     230

# %%
df_cardiovascular.to_csv("drugate_norm_updated.csv",index=False)
